# %% [markdown]
# 1 -- remove countryCode, pageID, pageTitle, Qid

# %%
import csv
col_keep = ['country', 'langWiki', 'views', 'date']  # Replace with your desired column names

with open('st07_data.csv', 'r', newline='') as infile:
    with open('cleaned_st07_date.csv', 'w', newline='') as outfile:
        reader = csv.reader(infile)
        writer = csv.writer(outfile)
        
        header = next(reader)  # Read the header row
        column_indices = [header.index(col) for col in col_keep]

        writer.writerow(col_keep)  # Write the new header
        for row in reader:
            new_row = [row[i] for i in column_indices]
            writer.writerow(new_row)

# %% [markdown]
# changing the domain of languages --> language title

# %%
langMaps={"en": "English", "fr": "French", "de": "German", "ja": "Japanese", "zh": "Chinese", "es": "Spanish", "fa": "Persian", "pl": "Polish", "nl": "Dutch", "he": "Hebrew", "pt": "Portuguese", "ru": "Russian", "id": "Indonesian", "ar": "Arabic", "ko": "Korean", "it": "Italian", "uk": "Ukrainian", "tr": "Turkish", "cs": "Czech", "sv": "Swedish", "vi": "Vietnamese", "simple": "Simple English", "no": "Norwegian", "fi": "Finnish", "ms": "Malay", "sr": "Serbian", "th": "Thai", "ro": "Romanian", "da": "Danish", "bn": "Bengali", "bg": "Bulgarian", "hi": "Hindi", "el": "Greek", "ca": "Catalan", "hu": "Hungarian", "sk": "Slovak", "hr": "Croatian", "az": "Azerbaijani", "zh-yue": "Cantonese", "et": "Estonian", "sw": "Swahili", "eu": "Basque", "lt": "Lithuanian", "hy": "Armenian", "sl": "Slovene", "lv": "Latvian", "uz": "Uzbek", "ta": "Tamil", "si": "Sinhala", "eo": "Esperanto", "sq": "Albanian", "ml": "Malayalam", "sh": "Serbo-Croatian", "mr": "Marathi", "ur": "Urdu", "be": "Belarusian", "gl": "Galician", "ka": "Georgian", "arz": "Egyptian Arabic", "kk": "Kazakh", "te": "Telugu", "af": "Afrikaans", "mk": "Macedonian", "my": "Burmese", "tl": "Tagalog", "bs": "Bosnian", "ha": "Hausa", "is": "Icelandic", "mn": "Mongolian", "kn": "Kannada", "so": "Somali", "ne": "Nepali", "ceb": "Cebuano", "jv": "Javanese", "nn": "Norwegian", "pa": "Punjabi", "la": "Latin", "be-tarask": "Belarusian", "cy": "Welsh", "ckb": "Kurdish", "oc": "Occitan", "as": "Assamese", "km": "Khmer", "azb": "South Azerbaijani", "wuu": "Wu Chinese", "ast": "Asturian", "ban": "Balinese", "tg": "Tajik", "bcl": "Central Bikol", "lb": "Luxembourgish", "yo": "Yoruba", "br": "Breton", "ky": "Kyrgyz", "ga": "Irish", "ku": "Kurdish", "rw": "Kinyarwanda", "gu": "Gujarati", "sco": "Scots", "bar": "Bavarian", "zh-min-nan": "Southern Min", "ig": "Igbo", "als": "Alemannic German", "tt": "Tatar", "war": "Waray", "mg": "Malagasy", "an": "Aragonese", "pnb": "Western Punjabi", "am": "Amharic", "ary": "Moroccan Arabic", "or": "Odia", "scn": "Sicilian", "lmo": "Lombard", "min": "Minangkabau", "sa": "Sanskrit", "dag": "Dagbani", "fy": "West Frisian", "zgh": "Standard Moroccan Amazigh", "zu": "Zulu", "ht": "Haitian Creole", "ba": "Bashkir", "vec": "Venetian", "fo": "Faroese", "bo": "Central Tibetan", "zh-classical": "Classical Chinese", "io": "Ido", "sat": "Santali", "ps": "Pashto", "yi": "Yiddish", "cv": "Chuvash", "eml": "Emilian\u2013Romagnol", "mt": "Maltese", "su": "Sundanese", "qu": "Quechua", "lo": "Lao", "ce": "Chechen", "hif": "Fiji Hindi", "kaa": "Karakalpak", "bh": "Bihari", "co": "Corsican", "tk": "Turkmen", "sd": "Sindhi", "bjn": "Banjarese", "rue": "Rusyn", "hyw": "Western Armenian", "szl": "Silesian", "mzn": "Mazanderani", "nr": "Southern Ndebele", "ilo": "Ilocano", "lg": "Luganda", "sah": "Yakut", "ia": "Interlingua", "crh": "Crimean Tatar", "mai": "Maithili", "nds": "Low German", "ang": "Old English", "tcy": "Tulu", "pdc": "Pennsylvania Dutch", "fur": "Friulian", "lld": "Ladin", "cdo": "Eastern Min", "pms": "Piedmontese", "ab": "Abkhaz", "map-bms": "Banyumasan", "li": "Limburgish", "nah": "Nahuatl", "hak": "Hakka Chinese", "lij": "Ligurian", "gpe": "Ghanaian Pidgin English", "pap": "Papiamento", "gd": "Scottish Gaelic", "xmf": "Mingrelian", "guc": "Wayuu", "ff": "Fula", "dv": "Maldivian", "mhr": "Meadow Mari", "sc": "Sardinian", "hsb": "Upper Sorbian", "gn": "Guarani", "ace": "Acehnese", "nap": "Neapolitan", "ug": "Uyghur", "nds-nl": "Dutch Low Saxon", "ks": "Kashmiri", "ie": "Interlingue", "iu": "Inuktitut", "om": "Oromo", "ext": "Extremaduran", "os": "Ossetian", "vo": "Volap\u00fck", "smn": "Inari S\u00e1mi", "tn": "Tswana", "wa": "Walloon", "kw": "Cornish", "gan": "Gan Chinese", "lfn": "Lingua Franca Nova", "mad": "Madurese", "gor": "Gorontalo", "csb": "Kashubian", "pcd": "Picard", "tw": "Twi", "diq": "Zaza", "bew": "Betawi", "glk": "Gilaki", "haw": "Hawaiian", "lad": "Judaeo-Spanish", "vls": "West Flemish", "xh": "Xhosa", "rki": "Arakanese", "av": "Avar", "gv": "Manx", "ay": "Aymara", "frp": "Franco-Proven\u00e7al", "bat-smg": "Samogitian", "dtp": "Dusun", "ee": "Ewe", "ln": "Lingala", "dsb": "Lower Sorbian", "nup": "Nupe", "sn": "Shona", "fon": "Fon", "mi": "M\u0101ori", "vep": "Veps", "wo": "Wolof", "kab": "Kabyle", "avk": "Kotava", "nv": "Navajo", "frr": "North Frisian", "st": "Sotho", "tum": "Tumbuka", "bi": "Bislama", "dty": "Doteli", "dz": "Dzongkha", "got": "Gothic", "pam": "Kapampangan", "krc": "Karachay-Balkar", "kv": "Komi", "mni": "Meitei", "zea": "Zeelandic", "ksh": "Ripuarian", "lez": "Lezgian", "pcm": "Nigerian Pidgin", "tly": "Talysh", "bxr": "Buryat", "chr": "Cherokee", "jam": "Jamaican Patois", "new": "Newar", "cu": "Old Church Slavonic", "skr": "Saraiki", "shi": "Shilha", "bbc": "Toba Batak", "ts": "Tsonga", "za": "Zhuang", "bm": "Bambara", "se": "Northern S\u00e1mi", "awa": "Awadhi", "bpy": "Bishnupriya Manipuri", "myv": "Erzya", "gag": "Gagauz", "kg": "Kongo", "mwl": "Mirandese", "tpi": "Tok Pisin", "udm": "Udmurt", "tay": "Atayal", "iba": "Iban", "olo": "Livvi-Karelian", "jbo": "Lojban", "nia": "Nias", "nso": "Northern Sotho", "roa-tara": "Tarantino", "ti": "Tigrinya", "gom": "Konkani", "ady": "Adyghe", "roa-rup": "Aromanian", "cbk-zam": "Zamboanga Chavacano", "mrj": "Hill Mari", "ki": "Kikuyu", "rm": "Romansh", "szy": "Sakizaya", "shn": "Shan", "ss": "Swazi", "tet": "Tetum", "tyv": "Tuvan", "anp": "Angika", "chy": "Cheyenne", "ik": "I\u00f1upiaq", "kbd": "Kabardian", "xal": "Kalmyk Oirat", "ltg": "Latgalian", "mdf": "Moksha", "pfl": "Palatine German", "sm": "Samoan", "fiu-vro": "V\u00f5ro", "inh": "Ingush", "rn": "Kirundi", "nov": "Novial", "blk": "Pa'O", "pag": "Pangasinan", "ami": "Amis", "ny": "Chewa", "cr": "Cree", "dga": "Dagaare", "kge": "Komering", "btm": "Mandailing Batak", "pnt": "Pontic Greek", "rmy": "Romani", "stq": "Saterland Frisian", "trv": "Seediq", "kcg": "Tyap", "arc": "Aramaic", "bdr": "West Coast Bajau", "ch": "Chamorro", "fat": "Fante", "mnw": "Mon", "syl": "Sylheti", "ty": "Tahitian", "to": "Tongan", "ve": "Venda", "bug": "Buginese", "knc": "Central Kanuri", "din": "Dinka", "gcr": "French Guianese Creole", "guw": "Gun", "nqo": "N'Ko", "sg": "Sango", "fj": "Fijian", "kl": "Greenlandic", "kbp": "Kabiye", "koi": "Komi-Permyak", "atj": "Atikamekw", "nrm": "Norman", "srn": "Sranan Tongo", "gur": "Farefare", "mos": "Moor\u00e9", "alt": "Southern Altai", "ak(closed)": "Akan", "lbe": "Lak", "rsk": "Pannonian Rusyn", "tdd": "Tai Nuea", "igl": "Igala", "ann": "Obolo", "pi": "Pali", "tig": "Tigre", "kus": "Kusaal", "pih(closed)": "Norfuk", "pwn": "Paiwan", "na(closed)": "Nauruan", "aa(closed)": "Afar", "lrc(closed)": "Northern Luri", "ii(closed)": "Nuosu", "hz(closed)": "Herero", "ho(closed)": "Hiri Motu", "mh(closed)": "Marshallese", "ng(closed)": "Ovambo", "cho(closed)": "Choctaw", "kr(closed)": "Kanuri", "kj(closed)": "Ovambo", "mus(closed)": "Muscogee", "tlh(deleted)": "Klingon", "mo(deleted)": "Romanian", "sep11(deleted)": "English", "ru-sib(deleted)": "fictitious \"artificial Siberian language\"", "test": "English", "test2": "English", "tokipona(deleted)": "Toki Pona", "ten(closed)": "English", "nostalgia": "English"}

# %%
with open('cleaned_st07_date.csv', 'r', newline='') as infile:
    with open('codeToLang.csv', 'w', newline='') as outfile:
        reader = csv.reader(infile)
        writer = csv.writer(outfile)
        writer.writerow(header)

        for row in reader:
            key = row[1].split('.')
            if key[0] in langMaps.keys():
                row[1] = langMaps[key[0]]
            writer.writerow(row)

# %% [markdown]
# renamed the file once again to 'st07_data.csv'

# %% [markdown]
# filtering csv file to only include countries with at least 1 entry a month

# %%
import pandas as pd


df = pd.read_csv('st07_data.csv')
df['date'] = pd.to_datetime(df['date'])

df['ym'] = df['date'].dt.to_period('M')
monthCount = df.groupby(['country', 'ym']).size().reset_index(name='count')

oneMonth = monthCount.groupby('country')['count'].count()
yesCountries = oneMonth[oneMonth > 9].index

filter = df[df['country'].isin(yesCountries)]

print(filter)
df.to_csv('cleaned.csv', columns=['country','langWiki','views','date'], index=False)
# Out:
#               country langWiki  views       date       ym
# 0           Argentina  Spanish    130 2023-02-06  2023-02
# 1               India    Hindi    256 2023-02-06  2023-02
# 2              Mexico  Spanish    135 2023-02-06  2023-02
# 3             Germany   German    114 2023-02-06  2023-02
# 4               India  English     92 2023-02-06  2023-02
# ...               ...      ...    ...        ...      ...
# 845299         Canada  English    142 2025-10-06  2025-10
# 845300        Germany   German    291 2025-10-06  2025-10
# 845301         France  English    559 2025-10-06  2025-10
# 845302         France   French    137 2025-10-06  2025-10
# 845303  United States  English    178 2025-10-06  2025-10
#
# [845304 rows x 5 columns]

# %%
len(yesCountries)
# Out:
# 98

# %% [markdown]
# renamed cleaned.csv to st07_data.csv
